# %% [markdown]
# # **aqui coloca um video no notbook** 👼

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo("Fn9adh4HWUU", width=640)

# %% [markdown]
# # **aqui começa a analise**👍

# %%
import pandas as pd

# %%
dados = pd.read_csv ('/content/listapacientes_nova.csv', sep=';')

# %%
dados
# Out:
#     numeroProntuario  ...  nomeLocalidade
# 0                  2  ...          Manaus
# 1                  3  ...          Manaus
# 2                  6  ...       Sao Paulo
# 3                  7  ...          Manaus
# 4                  8  ...          Manaus
# 5                  9  ...       Sao Paulo
# 6                 10  ...          Manaus
# 7                 11  ...          Manaus
# 8                 12  ...          Manaus
# 9                 21  ...       Sao Paulo
# 10                24  ...          Manaus
# 11                52  ...  Rio de Janeiro
# 12                53  ...          Manaus
# 13                54  ...          Manaus
# 14                56  ...          Manaus
# 15                64  ...       Sao Paulo
# 16                67  ...          Manaus
# 17                69  ...       Sao Paulo
# 18                73  ...          Manaus
# 19                76  ...       Sao Paulo
# 20                77  ...          Manaus
# 21                78  ...       Sao Paulo
# 22                85  ...       Sao Paulo
# 23                87  ...          Manaus
# 24                88  ...          Manaus
# 25               100  ...          Manaus
# 26               101  ...          Manaus
# 27               103  ...       Sao Paulo
# 28               109  ...          Manaus
# 29               115  ...          Manaus
# 30               117  ...       Sao Paulo
# 31               119  ...          Manaus
# 32               123  ...       Sao Paulo
# 33               127  ...          Manaus
# 34               128  ...          Manaus
# 35               129  ...          Manaus
# 36               130  ...          Manaus
# 37               134  ...  Rio de Janeiro
# 38               143  ...          Manaus
# 39               144  ...          Manaus
# 40               146  ...          Manaus
# 41               147  ...  Rio de Janeiro
# 42               151  ...          Manaus
# 43               152  ...          Manaus
# 44               154  ...          Manaus
# 45               156  ...          Manaus
# 46               157  ...  Rio de Janeiro
# 47               163  ...          Manaus
# 48               166  ...          Manaus
# 49               168  ...          Manaus
#
# [50 rows x 7 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   numeroProntuario  50 non-null     int64
#  1   nomepaciente      50 non-null     object
#  2   dataNascimento    50 non-null     object
#  3   falecidoData      0 non-null      float64
#  4   tipoSexo          50 non-null     object
#  5   tiposangue        50 non-null     object
#  6   nomeLocalidade    50 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.9+ KB

# %%
dados.describe()
# Out:
#        numeroProntuario  falecidoData
# count         50.000000           0.0
# mean          89.480000           NaN
# std           53.419495           NaN
# min            2.000000           NaN
# 25%           53.250000           NaN
# 50%           94.000000           NaN
# 75%          133.000000           NaN
# max          168.000000           NaN

# %% [markdown]
# # **Aqui eu faço um mapa dos dados** 🤜🤛

# %%
# !pip install geopandas

# %%
import geopandas as gpd

# %%
Brazil = gpd.read_file ('/content/BR_RG_Imediatas_2019.shp')

# %%
Brazil
# Out:
#      CD_RGI  ...                                           geometry
# 0    110001  ...  POLYGON ((-62.76414 -8.79806, -62.76415 -8.798...
# 1    110002  ...  POLYGON ((-63.68529 -9.83299, -63.68615 -9.825...
# 2    110003  ...  POLYGON ((-62.42262 -9.80462, -62.42273 -9.803...
# 3    110004  ...  POLYGON ((-62.71715 -10.87825, -62.70706 -10.8...
# 4    110005  ...  POLYGON ((-62.45310 -11.96851, -62.45331 -11.9...
# ..      ...  ...                                                ...
# 507  520019  ...  POLYGON ((-48.32444 -16.31735, -48.32513 -16.3...
# 508  520020  ...  POLYGON ((-48.05433 -15.50223, -48.07439 -15.5...
# 509  520021  ...  POLYGON ((-46.89898 -14.32961, -46.90026 -14.3...
# 510  520022  ...  POLYGON ((-47.82660 -14.35188, -47.82660 -14.3...
# 511  530001  ...  POLYGON ((-47.81455 -16.04995, -47.81478 -16.0...
#
# [512 rows x 4 columns]

# %%
Brazil.plot(figsize=(10,10))

# %% [markdown]
# # Professor agradeço sua atenção, e sou grato por ter estudado em sua Materia
# ## **Obrigado, tenha um bom dia** 🤜🤛

# %% [markdown]
# <a href="https://colab.research.google.com/github/MichelCavalcante/Analise-de-dados/blob/main/Analise_De_Dados_Prof%C2%B0_Dr_Felipe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **aqui coloca um video no notbook** 👼

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo("Fn9adh4HWUU", width=640)

# %% [markdown]
# # **aqui começa a analise**👍

# %%
import pandas as pd

# %%
dados = pd.read_csv ('/content/listapacientes_nova.csv', sep=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-b7419d86bd02> in <module>()
# ----> 1 dados = pd.read_csv ('/content/listapacientes_nova.csv', sep=';')
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
dados

# %%
dados.info()

# %%
dados.describe()

# %% [markdown]
# # **Aqui eu faço um mapa dos dados** 🤜🤛

# %%
# !pip install geopandas

# %%
import geopandas as gpd

# %%
Brazil = gpd.read_file ('/content/BR_RG_Imediatas_2019.shp')

# %%
Brazil

# %%
Brazil.plot(figsize=(10,10))

# %% [markdown]
# # Professor agradeço sua atenção, e sou grato por ter estudado em sua Materia
# ## **Obrigado, tenha um bom dia** 🤜🤛
